# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashish-Aaran/EDA/blob/main/21BDS0335.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# !wget -O prison.csv "https://raw.githubusercontent.com/salemprakash/EDA/main/Data/prison.csv"
# Out:
# --2025-02-16 11:00:29--  https://raw.githubusercontent.com/salemprakash/EDA/main/Data/prison.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 411534 (402K) [text/plain]
# Saving to: ‘prison.csv’
#
# prison.csv          100%[===================>] 401.89K  --.-KB/s    in 0.03s
#
# 2025-02-16 11:00:29 (12.4 MB/s) - ‘prison.csv’ saved [411534/411534]

# %%
df=pd.read_csv("prison.csv")
df.head(5)
# Out:
#    rownames  state  year  govelec   black   metro     unem      criv  \
# 0         1      1    80        0  0.2560  0.6320  0.08775  4.447868
# 1         2      1    81        0  0.2557  0.6362  0.10667  4.700944
# 2         3      1    82        1  0.2554  0.6404  0.14367  4.497580
# 3         4      1    83        0  0.2551  0.6446  0.13667  4.186833
# 4         5      1    84        0  0.2548  0.6488  0.11167  4.353239
#
#         crip     lcriv  ...  cag18_24  cag25_34    cunem    cblack  cmetro  \
# 0  44.476376  1.492425  ...  0.000077  0.001990  0.01675 -0.059999  0.0002
# 1  44.248787  1.547763  ...  0.000177  0.004632  0.01892 -0.030001  0.0042
# 2  42.050446  1.503539  ... -0.000712  0.000013  0.03700 -0.029999  0.0042
# 3  37.084393  1.431945  ... -0.001318  0.001163 -0.00700 -0.030001  0.0042
# 4  35.042255  1.470920  ... -0.002618  0.001297 -0.02500 -0.030001  0.0042
#
#          pris     lpris     gpris  final1  final2
# ...

# %%
print("Dataset Dimensions:", df.shape)
# Out:
# Dataset Dimensions: (714, 46)

# %%
print("Summary:")
display(df.describe(include='all'))
# Out:
# Summary:
#          rownames      state        year    govelec       black       metro  \
# count  714.000000  714.00000  714.000000  714.00000  714.000000  714.000000
# mean   357.500000   26.00000   86.500000    0.25070    0.105329    0.641727
# std    206.258333   14.72992    4.033955    0.43372    0.121210    0.225690
# min      1.000000    1.00000   80.000000    0.00000    0.002000    0.153000
# 25%    179.250000   13.00000   83.000000    0.00000    0.020250    0.457850
# 50%    357.500000   26.00000   86.500000    0.00000    0.071000    0.671350
# 75%    535.750000   39.00000   90.000000    0.75000    0.148075    0.815925
# max    714.000000   51.00000   93.000000    1.00000    0.703000    1.000000
#
#              unem        criv        crip       lcriv  ...    cag18_24  \
# count  714.000000  714.000000  714.000000  714.000000  ...  714.000000
# mean     0.068487    5.078585   46.435141    1.426112  ...   -0.002448
# ...

# %%
print("Checking for missing values:")
display(df.isnull().sum())
# Out:
# Checking for missing values:
# rownames    0
# state       0
# govelec     0
# black       0
# metro       0
# unem        0
# criv        0
# crip        0
# lcriv       0
# lcrip       0
# gcriv       0
# gcrip       0
# y81         0
# y82         0
# y83         0
# y84         0
# y85         0
# y86         0
# y87         0
# y88         0
# y89         0
# y90         0
# y91         0
# y92         0
# y93         0
# ag0_14      0
# ag15_17     0
# ag18_24     0
# ag25_34     0
# incpc       0
# polpc       0
# gincpc      0
# gpolpc      0
# cag0_14     0
# cag15_17    0
# cag18_24    0
# cag25_34    0
# cunem       0
# cblack      0
# cmetro      0
# pris        0
# lpris       0
# gpris       0
# final1      0
# final2      0
# dtype: int64

# %%
print("Total number of missing values:")
display(df.isnull().sum().sum())
# Out:
# Total number of missing values:
# 0

# %%
print("Data Types:")
display(df.dtypes)
# Out:
# Data Types:
# rownames      int64
# state         int64
# year          int64
# govelec       int64
# black       float64
# metro       float64
# unem        float64
# criv        float64
# crip        float64
# lcriv       float64
# lcrip       float64
# gcriv       float64
# gcrip       float64
# y81           int64
# y82           int64
# y83           int64
# y84           int64
# y85           int64
# y86           int64
# y87           int64
# y88           int64
# y89           int64
# y90           int64
# y91           int64
# y92           int64
# y93           int64
# ag0_14      float64
# ag15_17     float64
# ag18_24     float64
# ag25_34     float64
# incpc       float64
# polpc       float64
# gincpc      float64
# gpolpc      float64
# cag0_14     float64
# cag15_17    float64
# cag18_24    float64
# cag25_34    float64
# cunem       float64
# cblack      float64
# cmetro      float64
# pris        float64
# lpris       float64
# gpris       float64
# ...

# %%
# Range (Max - Min)
numeric_cols = df.select_dtypes(include=['number'])
print("Range:")
print(numeric_cols.max() - numeric_cols.min())
# Out:
# Range:
# rownames      713.000000
# state          50.000000
# govelec         1.000000
# black           0.701000
# metro           0.847000
# unem            0.158910
# criv           28.742365
# crip           67.427715
# lcriv           4.117904
# lcrip           1.438935
# gcriv           0.831519
# gcrip           0.443346
# y81             1.000000
# y82             1.000000
# y83             1.000000
# y84             1.000000
# y85             1.000000
# y86             1.000000
# y87             1.000000
# y88             1.000000
# y89             1.000000
# y90             1.000000
# y91             1.000000
# y92             1.000000
# y93             1.000000
# ag0_14          0.164263
# ag15_17         0.035135
# ag18_24         0.067236
# ag25_34         0.101040
# incpc       22976.307617
# polpc         746.828201
# gincpc          0.306814
# gpolpc          0.697550
# cag0_14         0.017144
# cag15_17        0.007911
# cag18_24        0.015963
# ...

# %%
# Interquartile Range (IQR)
print("Interquartile Range (IQR):")
print(numeric_cols.quantile(0.75) - numeric_cols.quantile(0.25))
# Out:
# Interquartile Range (IQR):
# rownames     356.500000
# state         26.000000
# govelec        0.750000
# black          0.127825
# metro          0.358075
# unem           0.027957
# criv           3.676239
# crip          15.720682
# lcriv          0.833612
# lcrip          0.341114
# gcriv          0.110513
# gcrip          0.080086
# y81            0.000000
# y82            0.000000
# y83            0.000000
# y84            0.000000
# y85            0.000000
# y86            0.000000
# y87            0.000000
# y88            0.000000
# y89            0.000000
# y90            0.000000
# y91            0.000000
# y92            0.000000
# y93            0.000000
# ag0_14         0.020824
# ag15_17        0.007115
# ag18_24        0.022090
# ag25_34        0.015519
# incpc       5936.833252
# polpc         67.825737
# gincpc         0.032010
# gpolpc         0.041787
# cag0_14        0.002948
# cag15_17       0.002222
# cag18_24       0.002503
# cag25_34       0.004604
# ...

# %%
# Interdecile Range
print("Interdecile Range:")
print(numeric_cols.quantile(0.90) - numeric_cols.quantile(0.10))
# Out:
# Interdecile Range:
# rownames      570.400000
# state          40.000000
# govelec         1.000000
# black           0.251070
# metro           0.628720
# unem            0.056095
# criv            7.011978
# crip           31.001215
# lcriv           1.643858
# lcrip           0.692374
# gcriv           0.204663
# gcrip           0.154749
# y81             0.000000
# y82             0.000000
# y83             0.000000
# y84             0.000000
# y85             0.000000
# y86             0.000000
# y87             0.000000
# y88             0.000000
# y89             0.000000
# y90             0.000000
# y91             0.000000
# y92             0.000000
# y93             0.000000
# ag0_14          0.054394
# ag15_17         0.014489
# ag18_24         0.036844
# ag25_34         0.032900
# incpc       10432.442285
# polpc         135.426703
# gincpc          0.069354
# gpolpc          0.093653
# cag0_14         0.005428
# cag15_17        0.003608
# cag18_24        0.005000
# ...

# %%
# Standard Deviation
print("Standard Deviation:")
print(numeric_cols.std())
# Out:
# Standard Deviation:
# rownames     206.258333
# state         14.729920
# govelec        0.433720
# black          0.121210
# metro          0.225690
# unem           0.022151
# criv           3.440078
# crip          12.117244
# lcriv          0.654660
# lcrip          0.265534
# gcriv          0.088556
# gcrip          0.060627
# y81            0.257720
# y82            0.257720
# y83            0.257720
# y84            0.257720
# y85            0.257720
# y86            0.257720
# y87            0.257720
# y88            0.257720
# y89            0.257720
# y90            0.257720
# y91            0.257720
# y92            0.257720
# y93            0.257720
# ag0_14         0.024092
# ag15_17        0.005494
# ag18_24        0.013811
# ag25_34        0.014443
# incpc       4086.769297
# polpc         86.722129
# gincpc         0.028538
# gpolpc         0.054256
# cag0_14        0.002241
# cag15_17       0.001401
# cag18_24       0.002047
# cag25_34       0.003081
# ...

# %%
# Skewness
print("Skewness:")
print(numeric_cols.skew())
# Out:
# Skewness:
# rownames     0.000000
# state        0.000000
# govelec      1.152817
# black        2.346253
# metro       -0.365218
# unem         0.837877
# criv         2.571302
# crip         0.516515
# lcriv       -0.426742
# lcrip       -0.260814
# gcriv       -0.177477
# gcrip        0.006381
# y81          3.335212
# y82          3.335212
# y83          3.335212
# y84          3.335212
# y85          3.335212
# y86          3.335212
# y87          3.335212
# y88          3.335212
# y89          3.335212
# y90          3.335212
# y91          3.335212
# y92          3.335212
# y93          3.335212
# ag0_14       1.077203
# ag15_17     -0.053078
# ag18_24      0.092981
# ag25_34      1.022826
# incpc        0.566083
# polpc        4.040439
# gincpc       0.466714
# gpolpc       0.695234
# cag0_14      0.058881
# cag15_17     0.023257
# cag18_24    -0.063655
# cag25_34     0.178204
# cunem        0.217579
# cblack      -2.217984
# cmetro       2.477760
# pris         3.224787
# ...

# %%
# Kurtosis
print("Kurtosis:")
print(numeric_cols.kurt())
# Out:
# Kurtosis:
# rownames     -1.200000
# state        -1.200925
# govelec      -0.672905
# black         7.550695
# metro        -0.894021
# unem          1.344003
# criv         11.866132
# crip          0.353569
# lcriv         0.563632
# lcrip         0.044114
# gcriv         1.880323
# gcrip         0.326164
# y81           9.149260
# y82           9.149260
# y83           9.149260
# y84           9.149260
# y85           9.149260
# y86           9.149260
# y87           9.149260
# y88           9.149260
# y89           9.149260
# y90           9.149260
# y91           9.149260
# y92           9.149260
# y93           9.149260
# ag0_14        3.426649
# ag15_17       0.081405
# ag18_24      -0.811906
# ag25_34       2.538131
# incpc        -0.022850
# polpc        22.425756
# gincpc        3.340877
# gpolpc       10.692627
# cag0_14       0.599178
# cag15_17     -0.588490
# cag18_24      1.033572
# cag25_34     -0.200917
# cunem         0.425903
# cblack       14.047307
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Univariate Analysis
numeric_cols = df.select_dtypes(include=[np.number]).columns[:5]
plt.figure(figsize=(12,6))
df[numeric_cols].hist(figsize=(15, 10), bins=20, layout=(4,3))
plt.suptitle("Distribution of Selected Numeric Features")
plt.show()

# %%
# Bivariate Analysis
corr_matrix = df[numeric_cols].corr()
plt.figure(figsize=(10,6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Matrix (Subset of Features)")
plt.show()

# %%
# Multivariate Analysis
sns.pairplot(df[numeric_cols])
plt.show()

# %%
#Boxplot
plt.figure(figsize=(12,6))
sns.boxplot(data=df[numeric_cols])
plt.xticks(rotation=90)
plt.title("Boxplot for Outlier Detection (Subset)")
plt.show()

# %%
df['year'] = df['year'] + 1900
df['year'] = pd.to_datetime(df['year'], format='%Y')
df.set_index('year', inplace=True)

# %%
numeric_cols = df.select_dtypes(include=['number']).columns
df_yearly = df[numeric_cols].groupby(df.index).mean()
selected_features = ['pris', 'criv', 'crip', 'unem', 'incpc']
fig, axes = plt.subplots(nrows=len(selected_features), ncols=1, figsize=(10, 12), sharex=True)
for i, col in enumerate(selected_features):
    axes[i].plot(df_yearly.index, df_yearly[col], linestyle='-', label=col)
    axes[i].set_ylabel(col)
    axes[i].legend()
    axes[i].grid()
plt.suptitle("Time Series Trends of Key Features", fontsize=14)
plt.xlabel("Year")
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()
