# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashish-Aaran/EDA/blob/main/21BDS0335.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Name: Ashish Aaran David
# # Reg.No: 21BDS0335
# # Github Link: https://github.com/Ashish-Aaran/EDA/blob/main/21BDS0335.ipynb
# # Dataset: prison.csv

# %% [markdown]
# # Data Collection

# %%
# !wget -O prison.csv "https://raw.githubusercontent.com/salemprakash/EDA/main/Data/prison.csv"
# Out:
# --2025-04-04 12:22:31--  https://raw.githubusercontent.com/salemprakash/EDA/main/Data/prison.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 411534 (402K) [text/plain]
# Saving to: ‘prison.csv’
#
# prison.csv          100%[===================>] 401.89K  1.99MB/s    in 0.2s
#
# 2025-04-04 12:22:31 (1.99 MB/s) - ‘prison.csv’ saved [411534/411534]

# %%
import pandas as pd
import numpy as np

# %%
ashish_david_df=pd.read_csv("prison.csv")
ashish_david_df.head(5)
# Out:
#    rownames  state  year  govelec   black   metro     unem      criv  \
# 0         1      1    80        0  0.2560  0.6320  0.08775  4.447868
# 1         2      1    81        0  0.2557  0.6362  0.10667  4.700944
# 2         3      1    82        1  0.2554  0.6404  0.14367  4.497580
# 3         4      1    83        0  0.2551  0.6446  0.13667  4.186833
# 4         5      1    84        0  0.2548  0.6488  0.11167  4.353239
#
#         crip     lcriv  ...  cag18_24  cag25_34    cunem    cblack  cmetro  \
# 0  44.476376  1.492425  ...  0.000077  0.001990  0.01675 -0.059999  0.0002
# 1  44.248787  1.547763  ...  0.000177  0.004632  0.01892 -0.030001  0.0042
# 2  42.050446  1.503539  ... -0.000712  0.000013  0.03700 -0.029999  0.0042
# 3  37.084393  1.431945  ... -0.001318  0.001163 -0.00700 -0.030001  0.0042
# 4  35.042255  1.470920  ... -0.002618  0.001297 -0.02500 -0.030001  0.0042
#
#          pris     lpris     gpris  final1  final2
# ...

# %%
ashish_david_df.tail(5)
# Out:
#      rownames  state  year  govelec   black   metro     unem      criv  \
# 709       710     51    89        0  0.0079  0.2817  0.06275  2.679039
# 710       711     51    90        1  0.0080  0.2960  0.05308  3.011013
# 711       712     51    91        0  0.0081  0.3103  0.05100  3.115721
# 712       713     51    92        0  0.0082  0.3246  0.05600  3.202151
# 713       714     51    93        0  0.0083  0.3389  0.05400  2.861702
#
#           crip     lcriv  ...  cag18_24  cag25_34    cunem  cblack  cmetro  \
# 709  37.655022  0.985458  ... -0.000770 -0.003921 -0.00025    0.01  0.0143
# 710  39.057270  1.102277  ...  0.000808 -0.005127 -0.00967    0.01  0.0143
# 711  40.965065  1.136460  ...  0.003559 -0.005790 -0.00208    0.01  0.0143
# 712  42.647312  1.163823  ...  0.002855 -0.006668  0.00500    0.01  0.0143
# 713  38.768085  1.051417  ...  0.003203 -0.003729 -0.00200    0.01  0.0143
#
#            pris     lpris     gpris  final1  final2
# ...

# %%
print("Dataset Dimensions:", ashish_david_df.shape)
# Out:
# Dataset Dimensions: (714, 46)

# %%
print("Summary:")
display(ashish_david_df.describe(include='all'))
# Out:
# Summary:
#          rownames      state        year    govelec       black       metro  \
# count  714.000000  714.00000  714.000000  714.00000  714.000000  714.000000
# mean   357.500000   26.00000   86.500000    0.25070    0.105329    0.641727
# std    206.258333   14.72992    4.033955    0.43372    0.121210    0.225690
# min      1.000000    1.00000   80.000000    0.00000    0.002000    0.153000
# 25%    179.250000   13.00000   83.000000    0.00000    0.020250    0.457850
# 50%    357.500000   26.00000   86.500000    0.00000    0.071000    0.671350
# 75%    535.750000   39.00000   90.000000    0.75000    0.148075    0.815925
# max    714.000000   51.00000   93.000000    1.00000    0.703000    1.000000
#
#              unem        criv        crip       lcriv  ...    cag18_24  \
# count  714.000000  714.000000  714.000000  714.000000  ...  714.000000
# mean     0.068487    5.078585   46.435141    1.426112  ...   -0.002448
# ...

# %% [markdown]
# # Handling Missing Values

# %%
print("Checking for missing values:")
display(ashish_david_df.isnull().sum())
# Out:
# Checking for missing values:
# rownames    0
# state       0
# year        0
# govelec     0
# black       0
# metro       0
# unem        0
# criv        0
# crip        0
# lcriv       0
# lcrip       0
# gcriv       0
# gcrip       0
# y81         0
# y82         0
# y83         0
# y84         0
# y85         0
# y86         0
# y87         0
# y88         0
# y89         0
# y90         0
# y91         0
# y92         0
# y93         0
# ag0_14      0
# ag15_17     0
# ag18_24     0
# ag25_34     0
# incpc       0
# polpc       0
# gincpc      0
# gpolpc      0
# cag0_14     0
# cag15_17    0
# cag18_24    0
# cag25_34    0
# cunem       0
# cblack      0
# cmetro      0
# pris        0
# lpris       0
# gpris       0
# final1      0
# final2      0
# dtype: int64

# %%
print("Total number of missing values in the dataset:")
display(ashish_david_df.isnull().sum().sum())
# Out:
# Total number of missing values in the dataset:
# np.int64(0)

# %%
print("Data Types:")
display(ashish_david_df.dtypes)
# Out:
# Data Types:
# rownames      int64
# state         int64
# year          int64
# govelec       int64
# black       float64
# metro       float64
# unem        float64
# criv        float64
# crip        float64
# lcriv       float64
# lcrip       float64
# gcriv       float64
# gcrip       float64
# y81           int64
# y82           int64
# y83           int64
# y84           int64
# y85           int64
# y86           int64
# y87           int64
# y88           int64
# y89           int64
# y90           int64
# y91           int64
# y92           int64
# y93           int64
# ag0_14      float64
# ag15_17     float64
# ag18_24     float64
# ag25_34     float64
# incpc       float64
# polpc       float64
# gincpc      float64
# gpolpc      float64
# cag0_14     float64
# cag15_17    float64
# cag18_24    float64
# cag25_34    float64
# cunem       float64
# cblack      float64
# cmetro      float64
# pris        float64
# lpris       float64
# gpris       float64
# ...

# %% [markdown]
# # Discretization and Binning

# %%
# Equal-Width Binning
ashish_david_category1 = pd.cut(ashish_david_df['pris'], bins=4)
pd.value_counts(ashish_david_category1)
# Out:
# <ipython-input-10-21e96918d69d>:3: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(ashish_david_category1)
# pris
# (19.561, 337.33]       642
# (337.33, 653.832]       64
# (970.335, 1286.838]      5
# (653.832, 970.335]       3
# Name: count, dtype: int64

# %%
# Equal-Frequency Binning
ashish_david_category2 = pd.qcut(ashish_david_df['pris'], q=4)
pd.value_counts(ashish_david_category2)
# Out:
# <ipython-input-11-4454a5399e62>:3: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(ashish_david_category2)
# pris
# (20.826, 113.039]      179
# (251.896, 1286.838]    179
# (113.039, 172.454]     178
# (172.454, 251.896]     178
# Name: count, dtype: int64

# %%
ashish_david_bins = [316,337,654,970,1287]
ashish_david_labels = ['Low', 'Medium', 'High', 'Very High']
ashish_david_category3 = pd.cut(ashish_david_df['pris'], bins=ashish_david_bins, labels=ashish_david_labels)
pd.value_counts(ashish_david_category3)
# Out:
# <ipython-input-12-fd0875ec965b>:4: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(ashish_david_category3)
# pris
# Medium       64
# Low          19
# Very High     5
# High          3
# Name: count, dtype: int64

# %% [markdown]
# # Statistical Analysis

# %%
ashish_david_cols = ashish_david_df.select_dtypes(include=['number']).iloc[:, :12]
# Mean
print("Mean:")
print(ashish_david_cols.mean())
# Out:
# Mean:
# rownames    357.500000
# state        26.000000
# year         86.500000
# govelec       0.250700
# black         0.105329
# metro         0.641727
# unem          0.068487
# criv          5.078585
# crip         46.435141
# lcriv         1.426112
# lcrip         3.803649
# gcriv         0.019184
# dtype: float64

# %%
# Median
print("Median:")
print(ashish_david_cols.median())
# Out:
# Median:
# rownames    357.500000
# state        26.000000
# year         86.500000
# govelec       0.000000
# black         0.071000
# metro         0.671350
# unem          0.066000
# criv          4.515549
# crip         45.185146
# lcriv         1.507526
# lcrip         3.810768
# gcriv         0.023894
# dtype: float64

# %%
# Mode
print("Mode:")
print(ashish_david_cols.mode().iloc[0])
# Out:
# Mode:
# rownames     1.000000
# state        1.000000
# year        80.000000
# govelec      0.000000
# black        0.003000
# metro        1.000000
# unem         0.075000
# criv         0.475628
# crip        20.965015
# lcriv       -0.743120
# lcrip        3.042855
# gcriv       -0.354280
# Name: 0, dtype: float64

# %%
# Standard Deviation
print("Standard Deviation:")
print(ashish_david_cols.std())
# Out:
# Standard Deviation:
# rownames    206.258333
# state        14.729920
# year          4.033955
# govelec       0.433720
# black         0.121210
# metro         0.225690
# unem          0.022151
# criv          3.440078
# crip         12.117244
# lcriv         0.654660
# lcrip         0.265534
# gcriv         0.088556
# dtype: float64

# %%
# Minimum Values
print("Minimum Values:")
print(ashish_david_cols.min())
# Out:
# Minimum Values:
# rownames     1.000000
# state        1.000000
# year        80.000000
# govelec      0.000000
# black        0.002000
# metro        0.153000
# unem         0.021420
# criv         0.475628
# crip        20.965015
# lcriv       -0.743120
# lcrip        3.042855
# gcriv       -0.354280
# dtype: float64

# %%
# Maximum Values
print("Maximum Values:")
print(ashish_david_cols.max())
# Out:
# Maximum Values:
# rownames    714.000000
# state        51.000000
# year         93.000000
# govelec       1.000000
# black         0.703000
# metro         1.000000
# unem          0.180330
# criv         29.217993
# crip         88.392731
# lcriv         3.374785
# lcrip         4.481790
# gcriv         0.477239
# dtype: float64

# %%
# Quartiles
print("Quartiles:")
print(ashish_david_cols.quantile([0.25, 0.50, 0.75]))
# Out:
# Quartiles:
#       rownames  state  year  govelec     black     metro      unem      criv  \
# 0.25    179.25   13.0  83.0     0.00  0.020250  0.457850  0.053000  2.824363
# 0.50    357.50   26.0  86.5     0.00  0.071000  0.671350  0.066000  4.515549
# 0.75    535.75   39.0  90.0     0.75  0.148075  0.815925  0.080958  6.500603
#
#            crip     lcriv     lcrip     gcriv
# 0.25  38.671989  1.038283  3.655116 -0.035040
# 0.50  45.185146  1.507526  3.810768  0.023894
# 0.75  54.392672  1.871895  3.996229  0.075473

# %%
# Range (Max - Min)
print("Range:")
print(ashish_david_cols.max() - ashish_david_cols.min())
# Out:
# Range:
# rownames    713.000000
# state        50.000000
# year         13.000000
# govelec       1.000000
# black         0.701000
# metro         0.847000
# unem          0.158910
# criv         28.742365
# crip         67.427715
# lcriv         4.117904
# lcrip         1.438935
# gcriv         0.831519
# dtype: float64

# %%
# Variance
print("Variance:")
print(ashish_david_cols.var())
# Out:
# Variance:
# rownames    42542.500000
# state         216.970547
# year           16.272791
# govelec         0.188113
# black           0.014692
# metro           0.050936
# unem            0.000491
# criv           11.834136
# crip          146.827597
# lcriv           0.428580
# lcrip           0.070508
# gcriv           0.007842
# dtype: float64

# %%
# Interquartile Range (IQR)
print("Interquartile Range (IQR):")
print(ashish_david_cols.quantile(0.75) - ashish_david_cols.quantile(0.25))
# Out:
# Interquartile Range (IQR):
# rownames    356.500000
# state        26.000000
# year          7.000000
# govelec       0.750000
# black         0.127825
# metro         0.358075
# unem          0.027957
# criv          3.676239
# crip         15.720682
# lcriv         0.833612
# lcrip         0.341114
# gcriv         0.110513
# dtype: float64

# %%
# Interdecile Range
print("Interdecile Range:")
print(ashish_david_cols.quantile(0.90) - ashish_david_cols.quantile(0.10))
# Out:
# Interdecile Range:
# rownames    570.400000
# state        40.000000
# year         11.000000
# govelec       1.000000
# black         0.251070
# metro         0.628720
# unem          0.056095
# criv          7.011978
# crip         31.001215
# lcriv         1.643858
# lcrip         0.692374
# gcriv         0.204663
# dtype: float64

# %%
# Standard Deviation
print("Standard Deviation:")
print(ashish_david_cols.std())
# Out:
# Standard Deviation:
# rownames    206.258333
# state        14.729920
# year          4.033955
# govelec       0.433720
# black         0.121210
# metro         0.225690
# unem          0.022151
# criv          3.440078
# crip         12.117244
# lcriv         0.654660
# lcrip         0.265534
# gcriv         0.088556
# dtype: float64

# %%
# Skewness
print("Skewness:")
print(ashish_david_cols.skew())
# Out:
# Skewness:
# rownames    0.000000
# state       0.000000
# year        0.000000
# govelec     1.152817
# black       2.346253
# metro      -0.365218
# unem        0.837877
# criv        2.571302
# crip        0.516515
# lcriv      -0.426742
# lcrip      -0.260814
# gcriv      -0.177477
# dtype: float64

# %%
# Kurtosis
print("Kurtosis:")
print(ashish_david_cols.kurt())
# Out:
# Kurtosis:
# rownames    -1.200000
# state       -1.200925
# year        -1.212390
# govelec     -0.672905
# black        7.550695
# metro       -0.894021
# unem         1.344003
# criv        11.866132
# crip         0.353569
# lcriv        0.563632
# lcrip        0.044114
# gcriv        1.880323
# dtype: float64

# %% [markdown]
# # Univariate Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns
ashish_david_cols = ashish_david_df.select_dtypes(include=[np.number]).columns[3:8]
plt.figure(figsize=(12,6))
ashish_david_df[ashish_david_cols].hist(figsize=(15, 10), bins=20, layout=(4,3))
plt.suptitle("Distribution of Key Features (21BDS0335)")
plt.show()

# %%
sns.FacetGrid(ashish_david_df).map(sns.distplot,"pris").add_legend()
plt.title("Distribution Plot (21BDS0335)")
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# Text(0.5, 1.0, 'Distribution Plot (21BDS0335)')

# %%
sns.boxplot(x="pris",data=ashish_david_df)
plt.title("Boxplot (21BDS0335)")
plt.xlabel("Prison Population per 100,000")
plt.show()

# %%
plt.figure(figsize=(6,5))
sns.boxplot(data=ashish_david_df[ashish_david_cols])
plt.xticks(rotation=90)
plt.title("Boxplot for Outlier Detection (21BDS0335)")
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
#Relationship between two features
np.corrcoef(ashish_david_df["pris"], ashish_david_df["criv"])
# Out:
# array([[1.        , 0.77627707],
#        [0.77627707, 1.        ]])

# %%
plt.figure(figsize=(8, 5))
plt.scatter(ashish_david_df["criv"], ashish_david_df["pris"])
plt.title("Scatter Plot for Violent Crimes vs Prison Population (21BDS0335)")
plt.xlabel("Violent Crimes per 100,000 (criv)")
plt.ylabel("Prison Population per 100,000 (pris)")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x=pd.qcut(ashish_david_df["incpc"], q=4), y=ashish_david_df["pris"])
plt.title("Box Plot for Prison Population vs Per Capita Income (21BDS0335)")
plt.xlabel("Per Capita Income (Binned)")
plt.ylabel("Prison Population per 100,000")
plt.show()

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(ashish_david_df,vars = ['pris', 'criv','incpc','unem'], kind="reg")
plt.suptitle("Pairplot with Regression (21BDS0335)")
plt.show()

# %%
ashish_david_correlation = ashish_david_df.corr(method='pearson', numeric_only=True)
print(ashish_david_correlation)
# Out:
#           rownames         state          year   govelec     black     metro  \
# rownames  1.000000  9.998087e-01  1.955778e-02  0.036490 -0.227058 -0.156246
# state     0.999809  1.000000e+00  7.669225e-15  0.037760 -0.227295 -0.156875
# year      0.019558  7.669225e-15  1.000000e+00 -0.064531  0.009919  0.030631
# govelec   0.036490  3.775974e-02 -6.453061e-02  1.000000 -0.017217 -0.015207
# black    -0.227058 -2.272950e-01  9.918937e-03 -0.017217  1.000000  0.307554
# metro    -0.156246 -1.568753e-01  3.063085e-02 -0.015207  0.307554  1.000000
# unem     -0.059854 -5.343809e-02 -3.285952e-01  0.041834  0.189467 -0.018257
# criv     -0.311302 -3.142361e-01  1.469445e-01 -0.028923  0.700576  0.575134
# crip     -0.285356 -2.844549e-01 -4.885270e-02 -0.003979  0.276062  0.565004
# lcriv    -0.336331 -3.389586e-01  1.310516e-01 -0.050357  0.583805  0.654865
# lcrip    -0.291249 -2.904717e-01 -4.260759e-02 -0.006364  0.248837  0.571609
# ...

# %%
ashish_david_corr_matrix = ashish_david_df[ashish_david_cols].corr()
plt.figure(figsize=(5,4))
sns.heatmap(ashish_david_corr_matrix,annot=True,cmap='coolwarm')
plt.title("Correlation Matrix for Five Features (21BDS0335)")
plt.show()

# %% [markdown]
# # Time Series Analysis

# %%
ashish_david_df['year'] = ashish_david_df['year'] + 1900
ashish_david_df['year'] = pd.to_datetime(ashish_david_df['year'], format='%Y')
ashish_david_df.set_index('year', inplace=True)

# %%
sns.set(rc={'figure.figsize':(11, 4)})
plt.rcParams['figure.figsize'] = (8,5)
plt.rcParams['figure.dpi'] = 150

# %%
# Checking the income growth trends over years
ashish_david_df['gincpc'].plot(marker=".",linewidth=0.25) # gincpc represents the growth rate of per capita income
plt.title('Time Series Plot for gincpc (21BDS0335)')
plt.xlabel('Year')
plt.ylabel('gincpc')
plt.show()

# %%
ashish_david_cols = ashish_david_df.select_dtypes(include=['number']).columns
ashish_david_df_yearly = ashish_david_df[ashish_david_cols].groupby(ashish_david_df.index).mean()
ashish_david_selected_features = ['pris', 'criv', 'crip', 'unem', 'incpc']

# %%
fig, ashish_david_axes = plt.subplots(nrows=len(ashish_david_selected_features), ncols=1, figsize=(10, 12), sharex=True)
for i, col in enumerate(ashish_david_selected_features):
    ashish_david_axes[i].plot(ashish_david_df_yearly.index, ashish_david_df_yearly[col],marker="*",linestyle='-', label=col)
    ashish_david_axes[i].set_ylabel(col)
plt.suptitle("Time Series Trends (21BDS0335)", fontsize=14)
plt.xlabel("Year")
plt.show()

# %% [markdown]
# # Dimensionality Reduction (PCA)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
ashish_david_numeric_cols = ashish_david_df.select_dtypes(include=['float64', 'int64']).columns
ashish_david_df_numeric = ashish_david_df[ashish_david_numeric_cols]

# %%
X = ashish_david_df_numeric.drop(columns=['pris'])
y = ashish_david_df_numeric['pris']

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
pca = PCA(n_components=30)
X_pca = pca.fit_transform(X_scaled)
print(f"Explained Variance : {sum(pca.explained_variance_ratio_):.2f}")
# Out:
# Explained Variance : 0.97

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
# Split into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size=0.2, random_state=42)

# %%
# Training Linear Regression model
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predictions
y_pred = regressor.predict(X_test)

# %%
# Data frame with actual and predicted values of y
ashish_david_evaluate = pd.DataFrame({'Actual': y_test.values.flatten(),
'Predicted': y_pred.flatten()})
ashish_david_evaluate.head(10)
# Out:
#        Actual   Predicted
# 0  881.318665  791.959720
# 1   58.549343   53.734561
# 2  375.794617  291.648347
# 3   50.139420   25.566152
# 4  265.898712  303.574503
# 5  100.900223  128.848126
# 6  259.204590  276.842027
# 7   63.518135   17.541962
# 8  153.865021  191.716209
# 9  217.987183  251.513469

# %%
ashish_david_evaluate.head(10).plot(kind = 'bar')
plt.title("Actual vs Predicted Values - 21BDS0335")
plt.show()

# %% [markdown]
# # Model Evaluation

# %%
# R2 Score
print(f"R2 score: {r2_score(y_test, y_pred)}")
# Out:
# R2 score: 0.9084441139448847

# %%
# Mean Absolute Error (MAE)
print(f"MAE score: {mean_absolute_error(y_test, y_pred)}")
# Out:
# MAE score: 29.14354269274224

# %%
# Mean Squared Error (MSE)
print(f"MSE score: {mean_squared_error(y_test, y_pred)}")
# Out:
# MSE score: 1325.6153045986086
